# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 이미지 불러오기
img_path = '/home/kiwi/github_package/rokeypj_ws/src/turtlebot3_autorace_camera/turtlebot3_autorace_camera/saved_img/' \
+ "01.jpg"

# image_bgr = cv2.imread('/home/kiwi/github_package/rokeypj_ws/src/turtlebot3_autorace_camera/turtlebot3_autorace_camera/saved_img/saved_image_20250617_200339.jpg')
image_bgr = cv2.imread(img_path)

image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# BGR → HSV 변환
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(image_hsv)


# 채널 통계 출력
print(f'Hue: min={h.min()}, max={h.max()}, mean={h.mean():.2f}')
print(f'Saturation: min={s.min()}, max={s.max()}, mean={s.mean():.2f}')
print(f'Value: min={v.min()}, max={v.max()}, mean={v.mean():.2f}')

# 이미지 및 히스토그램 시각화
plt.figure(figsize=(16, 8))

# 원본 이미지
plt.subplot(2, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

# Hue 히스토그램
plt.subplot(2, 3, 2)
plt.hist(h.ravel(), bins=180, range=(0, 180), color='red')
plt.title('Hue Histogram')

# Saturation 히스토그램
plt.subplot(2, 3, 3)
plt.hist(s.ravel(), bins=256, range=(0, 256), color='green')
plt.title('Saturation Histogram')

# Value 히스토그램
plt.subplot(2, 3, 4)
plt.hist(v.ravel(), bins=256, range=(0, 256), color='blue')
plt.title('Value Histogram')

# # H 채널 이미지
# plt.subplot(2, 3, 5)
# plt.imshow(h, cmap='hsv')
# plt.title('Hue Channel')
# plt.axis('off')

# # V 채널 이미지
# plt.subplot(2, 3, 6)
# plt.imshow(v, cmap='gray')
# plt.title('Value Channel')
# plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Hue: min=0, max=173, mean=63.78
# Saturation: min=0, max=200, mean=17.41
# Value: min=28, max=168, mean=88.68
